# %% [markdown]
# ### Chapter 5, Section 5: The Substitution Rule
#
# - This section gives you a nice trick.
# - Problems: Paper (1, 3, 5, 7, 9, 11, 13, 17, 19, 21, 23, 27, 33, 37, 43, 51, 55, 57, 63, 71).
