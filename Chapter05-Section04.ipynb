# %% [markdown]
# ### Chapter 5, Section 4: Indefinite Integrals and the Net Change Theorem
#
# - This section gives you a table of definite integrals (p 410)
# - Problems: Paper (1, 3, 5, 7, 13, 17, 19, 21, 23, 27, 33, 37, 43, 51, 57 ).
